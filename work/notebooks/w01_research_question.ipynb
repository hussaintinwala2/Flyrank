# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hussaintinwala2/Flyrank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## 1. My Lane (or Freestyle) and Why
#
# I chose "Lane 2: Content Refresh / Opportunity Scoring" because it focuses on helping content teams decide which webpages should be reviewed and updated first. Organizations often manage thousands of pages, making it difficult to manually identify which ones need attention.
#
# This lane aims to support a practical business decision by prioritizing pages that are more likely to benefit from a content refresh. Rather than updating every page, the goal is to help editors use their limited time more effectively by focusing on the highest-priority pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## 2. The Question: Decision, Action, Cost of a Wrong Call
#
# The decision this project aims to improve is **which content pages should be prioritized for refresh or review**. Since content teams have limited time and resources, they cannot update every page, so they need a way to decide which pages deserve attention first.
#
# The primary users of this output are **SEO managers and content editors**. They can use the recommended priority list to decide which pages to update, improve, or monitor before others.
#
# A wrong recommendation has two possible costs. If a page is incorrectly marked as high priority, editors may spend time updating content that did not need immediate attention. If an important page is missed, it may continue to lose traffic or engagement, reducing the effectiveness of the content strategy.
#
# Machine learning is useful because it can combine many signals from the data to help rank pages by priority. The goal is not to replace human judgment but to support better and more consistent decision-making.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ### Interpretation
#
# The starter dataset contains **30,000 content pages** from **32 unique clients**, providing a diverse dataset for analysis. The trend distribution shows that **16,262 pages have a downward trend**, which is more than half of all pages in the dataset.
#
# These numbers support my choice of the **Content Refresh / Opportunity Scoring** lane because they indicate that many pages may require attention, while content teams have limited time and resources. A system that helps prioritize which pages should be reviewed first could improve the efficiency of content refresh decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load the starter dataset
df = pd.read_csv("content_refresh_anonymized.csv")

print("Dataset Shape (Rows, Columns):", df.shape)
print("Number of Unique Clients:", df["client_id"].nunique())

print("\nTrend Direction Distribution:")
print(df["trend_direction"].value_counts())
declining_pct = (df["trend_direction"] == "down").mean() * 100
print(f"Pages with downward trend: {declining_pct:.2f}%")
# Out:
# Dataset Shape (Rows, Columns): (30000, 44)
# Number of Unique Clients: 32
#
# Trend Direction Distribution:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
# Pages with downward trend: 54.21%

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## 4. Careful Words: What I Can and Can't Claim
#
# This project is intended to provide **decision support** by helping content teams identify pages that may deserve a higher priority for review. Any recommendations will be based on patterns observed in the available data and should be considered as guidance rather than certainty.
#
# This project **cannot prove why** a page gains or loses traffic, cannot predict future Google algorithm updates, and cannot guarantee that refreshing a recommended page will improve its performance. Final decisions should always include human review and domain expertise.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
